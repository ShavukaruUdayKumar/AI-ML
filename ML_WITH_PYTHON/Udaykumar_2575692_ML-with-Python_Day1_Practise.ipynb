# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('udayk.csv')
df
# Out:
#       Living Area  Bathrooms  Bedrooms  Lot Size  Age  Fireplace   Price
# 0            1982        1.0         3      2.00  133          0  142212
# 1            1676        1.5         3      0.38   14          1  134865
# 2            1694        2.0         3      0.96   15          1  118007
# 3            1800        1.0         2      0.48   49          1  138297
# 4            2088        1.0         3      1.84   29          1  129470
# ...           ...        ...       ...       ...  ...        ...     ...
# 1042         1802        2.0         4      0.97   56          1  107695
# 1043         3239        3.5         4      2.50    1          1  236737
# 1044         1440        2.0         2      0.61   66          1  154829
# 1045         2030        2.5         3      1.00    3          1  179492
# 1046         2097        2.5         3      1.93   10          1  189108
#
# [1047 rows x 7 columns]

# %%
df.head()
# Out:
#    Living Area  Bathrooms  Bedrooms  Lot Size  Age  Fireplace   Price
# 0         1982        1.0         3      2.00  133          0  142212
# 1         1676        1.5         3      0.38   14          1  134865
# 2         1694        2.0         3      0.96   15          1  118007
# 3         1800        1.0         2      0.48   49          1  138297
# 4         2088        1.0         3      1.84   29          1  129470

# %%
df.isna().sum()
# Out:
# Living Area    0
# Bathrooms      0
# Bedrooms       0
# Lot Size       0
# Age            0
# Fireplace      0
# Price          0
# dtype: int64

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Living Area'}>,
#         <Axes: title={'center': 'Bathrooms'}>,
#         <Axes: title={'center': 'Bedrooms'}>],
#        [<Axes: title={'center': 'Lot Size'}>,
#         <Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Fireplace'}>],
#        [<Axes: title={'center': 'Price'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
df.describe()
# Out:
#        Living Area    Bathrooms     Bedrooms     Lot Size          Age  \
# count  1047.000000  1047.000000  1047.000000  1047.000000  1047.000000
# mean   1807.302770     1.918338     3.183381     0.569580    28.061127
# std     641.460916     0.641735     0.750265     0.777879    34.900899
# min     672.000000     1.000000     1.000000     0.000000     0.000000
# 25%    1336.000000     1.500000     3.000000     0.210000     6.000000
# 50%    1672.000000     2.000000     3.000000     0.390000    18.000000
# 75%    2206.000000     2.500000     4.000000     0.600000    34.000000
# max    4534.000000     4.500000     6.000000     9.000000   247.000000
#
#          Fireplace          Price
# count  1047.000000    1047.000000
# mean      0.593123  163862.125119
# std       0.491486   67651.558917
# min       0.000000   16858.000000
# 25%       0.000000  112014.000000
# 50%       1.000000  151917.000000
# 75%       1.000000  205235.000000
# max       1.000000  446436.000000

# %%
x=df.iloc[:,:1]
x.head(5)
# Out:
#    Living Area
# 0         1982
# 1         1676
# 2         1694
# 3         1800
# 4         2088

# %%
y=df.iloc[:,-1:]
y.head(5)
# Out:
#     Price
# 0  142212
# 1  134865
# 2  118007
# 3  138297
# 4  129470

# %%
df.corr()
# Out:
#              Living Area  Bathrooms  Bedrooms  Lot Size       Age  Fireplace  \
# Living Area     1.000000   0.722649  0.664347  0.200180 -0.263168   0.481436
# Bathrooms       0.722649   1.000000  0.491798  0.100993 -0.443830   0.444700
# Bedrooms        0.664347   0.491798  1.000000  0.140682 -0.060598   0.295873
# Lot Size        0.200180   0.100993  0.140682  1.000000  0.015135   0.052765
# Age            -0.263168  -0.443830 -0.060598  0.015135  1.000000  -0.248794
# Fireplace       0.481436   0.444700  0.295873  0.052765 -0.248794   1.000000
# Price           0.776396   0.670189  0.471074  0.155284 -0.363354   0.460237
#
#                 Price
# Living Area  0.776396
# Bathrooms    0.670189
# Bedrooms     0.471074
# Lot Size     0.155284
# Age         -0.363354
# Fireplace    0.460237
# Price        1.000000

# %%
plt.scatter(x,y)
plt.title('House prices')
plt.xlabel('Living Area')
plt.ylabel('Price')
plt.show()

# %%
import sklearn
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest=train_test_split(x,y, test_size=0.2, random_state=42)

# %%
df.shape
# Out:
# (1047, 7)

# %%
xtrain.shape
# Out:
# (837, 1)

# %%
ytest.shape
# Out:
# (210, 1)

# %% [markdown]
# # Using Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lin_reg=LinearRegression()
print('Training Started.......\n')
print()
lin_reg.fit(xtrain,ytrain)
print()
print('Training Completed.....')
print()
print('Testing invoked......\n')
ypred=lin_reg.predict(xtest)
print('Predicted Total Payment \n', ypred)
print('\n Testing is also completed....\n')
# Out:
# Training Started.......
#
#
#
# Training Completed.....
#
# Testing invoked......
#
# Predicted Total Payment
#  [[203030.88389531]
#  [173537.30664426]
#  [218305.79442753]
#  [100493.98447155]
#  [ 83512.83393307]
#  [101468.97876084]
#  [172481.06283086]
#  [100006.48732691]
#  [146887.46273698]
#  [152656.17894861]
#  [128200.07219224]
#  [291267.86707613]
#  [170206.07615585]
#  [137706.26651282]
#  [164681.10851654]
#  [127956.32361991]
#  [214162.06869805]
#  [ 87656.55966256]
#  [189705.96194167]
#  [251455.60026342]
#  [171343.56949336]
#  [166468.5980469 ]
#  [ 91556.53681972]
#  [196449.6724426 ]
#  [118856.37691986]
#  [155581.16181649]
#  [161431.12755223]
#  [155581.16181649]
#  [143556.23224857]
#  [164193.61137189]
#  [138681.26080211]
#  [127550.07599937]
#  [210505.84011321]
#  [115931.39405199]
#  [148106.20559859]
#  [144206.22844143]
#  [112356.41499126]
#  [121131.36359488]
#  [132993.79411458]
#  [150056.19417717]
#  [146806.21321287]
#  [101306.47971263]
#  [159968.6361183 ]
#  [137706.26651282]
#  [120806.36549845]
#  [209124.59820338]
#  [165412.3542335 ]
#  [178656.02666304]
#  [205143.37152211]
#  [178331.02856661]
#  [220418.28205433]
#  [118856.37691986]
#  [ 81156.59773395]
#  [340992.57582997]
#  [195068.43053277]
#  [182149.75619966]
#  [189380.96384524]
#  [137381.26841639]
#  [233336.95638743]
#  [137706.26651282]
#  [211480.8344025 ]
#  [303049.04807173]
#  [148431.20369502]
#  [107400.1940207 ]
#  [239918.16784015]
#  [184668.491447  ]
#  [137706.26651282]
#  [149731.19608074]
#  [263643.02887956]
#  [159806.13707008]
#  [ 95212.76540456]
#  [147537.45892984]
#  [212862.07631233]
#  [113656.40737698]
#  [327830.15292454]
#  [162243.62279331]
#  [116906.38834128]
#  [215218.31251145]
#  [304674.03855388]
#  [122918.85312524]
#  [139981.25318783]
#  [189624.71241756]]
#
#  Testing is also completed....

# %%
ytest
# Out:
#       Price
# 352  202836
# 560  226304
# 874  236829
# 980   93174
# 31    65325
# ..      ...
# 816  233876
# 538  155713
# 440   64552
# 852  128434
# 209  201616
#
# [210 rows x 1 columns]

# %%
diff=ytest-ypred
diff
# Out:
#              Price
# 352    -194.883895
# 560   52766.693356
# 874   18523.205572
# 980   -7319.984472
# 31   -18187.833933
# ..             ...
# 816   18657.687489
# 538 -148961.038554
# 440  -58366.853125
# 852  -11547.253188
# 209   11991.287582
#
# [210 rows x 1 columns]

# %%
#Visualize the training dataset
plt.scatter (xtrain, ytrain, color='green')
plt.plot(xtrain, lin_reg.predict(xtrain), color='blue')
plt.title('House Prices (Training Dataset)')
plt.xlabel('Living Area')
plt.ylabel('Price')
plt.show()

# %%
#Visualize the test dataset
plt.scatter (xtest, ytest, color='yellow')
plt.plot(xtest, lin_reg.predict(xtest), color='red')
plt.title('House Prices(Test Dataset)')
plt.xlabel('Living Area')
plt.ylabel('Price')
plt.show()

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import explained_variance_score
print('Mean Squared Error: \t', mean_squared_error(ytest, ypred))
print()
print('RMSE: \t', np.sqrt(mean_squared_error(ytest, ypred)))
print()
print('Variance Score:\t', explained_variance_score (ytest,ypred))
print()
print('R-Square: \t', r2_score (ytest, ypred))
# Out:
# Mean Squared Error: 	 1896957512.8755126
#
# RMSE: 	 43554.07573207716
#
# Variance Score:	 0.616568466678611
#
# R-Square: 	 0.61560507111622

# %% [markdown]
# # Multiple Linear Regression

# %%
xm=df.iloc[:,0:3]
xm.head(5)
# Out:
#    Living Area  Bathrooms  Bedrooms
# 0         1982        1.0         3
# 1         1676        1.5         3
# 2         1694        2.0         3
# 3         1800        1.0         2
# 4         2088        1.0         3

# %%
ym=df.iloc[:,-1:]
ym.head(5)
# Out:
#     Price
# 0  142212
# 1  134865
# 2  118007
# 3  138297
# 4  129470

# %%
import sklearn
from sklearn.model_selection import train_test_split
xmtrain, xmtest, ymtrain, ymtest=train_test_split(xm,ym, test_size=0.2, random_state=42)

# %%
xmtrain.shape
# Out:
# (837, 3)

# %%
xmtest.shape
# Out:
# (210, 3)

# %%
ymtest.shape
# Out:
# (210, 1)

# %%
from sklearn.linear_model import LinearRegression
lin_reg=LinearRegression()
print('Training Started.......\n')
print()
lin_reg.fit(xmtrain,ymtrain)
print()
print('Training Completed.....')
print()
#  [192571.26829012]
#  [158327.8155875 ]
#  [142882.82023775]
#  [128365.34833661]
#  [111166.59387533]
#  [100824.57055743]
#  [210490.72154583]
#  [ 77469.00149931]
#  [236822.05723022]
#  [138460.2444768 ]
#  [184975.86138655]
#  [138460.2444768 ]
#  [181548.84870131]
#  [295608.29503721]
#  [130406.53714935]
#  [176912.39392128]
#  [137643.76895171]
#  [172499.57829815]
#  [200327.78577854]
#  [139591.88680669]
#  [106320.50915898]
#  [125474.43584016]
#  [ 86647.29679174]
#  [167532.68552048]
#  [110291.83886095]
#  [228589.26235215]
#  [118048.35634938]
#  [132200.59878439]
#  [140365.35403536]
#  [179779.81839693]
#  [125635.54642501]
#  [185971.42446225]
#  [101854.92510162]
#  [200426.36779134]
#  [107059.18491917]
#  [124852.31905852]
#  [147791.43352615]
#  [147042.99762814]
#  [209470.12713946]
#  [203958.91734506]
#  [133425.31207204]
#  [215228.46411157]
#  [152947.17399224]
#  [155139.71325202]
#  [271045.98965721]
#  [160174.64565679]
#  [283769.3999233 ]
#  [306173.95751201]
#  [252267.05257997]
#  [136360.77617479]
#  [111302.67312951]
#  [144719.89016922]
#  [166978.60836593]
#  [168636.59074679]
#  [211919.55371475]
#  [277305.63534962]
#  [132200.59878439]
#  [237842.65163659]
#  [ 90278.42835826]
#  [181428.04063998]
#  [125474.43584016]
#  [179779.81839693]
#  [158133.45684404]
#  [102170.09190641]
#  [117154.08105937]
#  [169496.07456831]
#  [213892.70290041]
#  [112706.47396776]
#  [196260.67934591]
#  [114092.29784026]
#  [252267.05257997]
#  [230086.13414817]
#  [290029.04561571]
#  [141181.82956046]
#  [ 93408.25120446]
#  [252080.91066445]
#  [178986.83089263]
#  [132200.59878439]
#  [136316.22456849]
#  [257029.82647637]
#  [177534.51070292]
#  [ 83202.30714075]
#  [140433.39366246]
#  [214505.05954423]
#  [119520.19681472]
#  [364435.39857791]
#  [152748.566166  ]
#  [108828.21522355]
#  [216478.20872988]
#  [304803.40483237]
#  [106403.81997893]
#  [134105.70834295]
#  [195045.72619608]]
#
#  Testing is also completed....

# %%
diff2=ymtest-ympred
diff2
# Out:
#              Price
# 352   15931.541034
# 560   50684.358993
# 874   -9061.847909
# 980    5549.117098
# 31   -15538.928489
# ..             ...
# 816   17397.791270
# 538 -149090.404832
# 440  -41851.819979
# 852   -5671.708343
# 209    6570.273804
#
# [210 rows x 1 columns]

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import explained_variance_score
print('Mean Squared Error: \t', mean_squared_error(ymtest, ympred))
print()
print('RMSE: \t', np.sqrt(mean_squared_error(ymtest, ympred)))
print()
print('Variance Score:\t', explained_variance_score (ymtest,ympred))
print()
print('R-Square: \t', r2_score (ymtest, ympred))
# Out:
# Mean Squared Error: 	 1867004563.7777746
#
# RMSE: 	 43208.84821165423
#
# Variance Score:	 0.622754190761745
#
# R-Square: 	 0.621674665010725
