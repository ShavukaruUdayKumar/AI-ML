# %% [markdown]
# # Exceptions and Command-Line Arguments

# %% [markdown]
# # 1. Write a python program with Exception handling to input marks for five subjects Physics, Chemistry, Biology, Mathematics, and Computer. Calculate the percentage and grade accordingto thefollowing:
#
# i) Percentage >= 90%: Grade A
#
# ii) Percentage >= 80%: Grade B
#
# iii) Percentage >= 70%: Grade C
#
# iv) Percentage >= 60%: Grade D
#
# v) Percentage >= 40%: Grade E
#
# vi) Percentage < 40%: Grade F

# %%
import sys

try:
    physics=int(input('enter physics marks: '))
    chemistry=int(input('enter chemistry marks:'))
    biology=int(input('enter biology marks:'))
    mathematics=int(input('enter mathematics marks:'))
    computer=int(input('enter computer marks:'))
    
    total_marks=physics+chemistry+biology+mathematics+computer
    percentage=(total_marks/500)*100
    if percentage>=90:
        grade='A'
    elif percentage>=80:
        grade='B'
    elif percentage>=70:
        grade='C'
    elif percentage>=60:
        grade='D'
    elif percentage>=40:
        grade='E'
    else:
        grade='F'
        
    print("Percentage: ", percentage) 
    print("Grade: ", grade)
        
except ValueError:
    print("Invalid input, please give a number")
    print(sys.exc_info()[0])
    print(sys.exc_info()[1])
# Out:
# enter physics marks: 92
# enter chemistry marks:80
# enter biology marks:84
# enter mathematics marks:88
# enter computer marks:84
# Percentage:  85.6
# Grade:  B

# %% [markdown]
# # 2. Write a python program with Exception handling to input electricity unit charges and calculatethe total electricity bill according to the given condition:
#
# i) For the first 50 units Rs. 0.50/unit
#
# ii) For the next 100 units Rs. 0.75/unit
#
# iii) For the next 100 units Rs. 1.20/unit
#
# iv) For units above 250 Rs. 1.50/unit
#
# v) An additional surcharge of 20% is added to the bill.

# %%
try:
    
    electric_units=float(input('enter electricity units: '))
    
    if electric_units<=50:
        charge = electric_units*0.50
    elif electric_units<=150:
        charge = 50*0.50+(electric_units-50)*0.75
    elif electric_units<=250:
        charge = 50*0.50+100*0.75+(electric_units-150)*1.20
    else:
        charge = 50*0.50+100*0.75+100*1.20+(electric_units-250)*1.50
     
    total_bill= charge+charge*0.20 
    print("Total Electricity bill = ", total_bill)

except ValueError:
    
    print("Invalid input, please give a number")
    print(sys.exc_info()[0])
    print(sys.exc_info()[1])
# Out:
# enter electricity units: 300
# Total Electricity bill =  354.0

# %% [markdown]
# # 3. Write a python program with Exception handling to input the week number and print the weekday.

# %%
try:
    week_num=int(input("enter the weekday number: "))
    weekday_num=(week_num-1)%7
    if weekday_num==0:
        print('Sunday')
    elif weekday_num==1:
        print('Monday')
    elif weekday_num==2:
        print('Tuesday')
    elif weekday_num==3:
        print('Wednesday')
    elif weekday_num==4:
        print('Thursday')
    elif weekday_num==5:
        print('Friday')
    else:
        print('Saturday') 
        
except ValueError:
    print("Invalid input, please give a number")
    print(sys.exc_info()[0])
    print(sys.exc_info()[1])
# Out:
# enter the weekday number: 59
# Tuesday

# %% [markdown]
# # 4. Write a Python program to implement word count using command line arguments.
#
# i) Create a text document “apple.txt” whch contains text for wordcount.
#
# ii) Create a wordcount program which calls the “apple.txt” document by opening the file.
#
# iii) If the word is present again in the “aaple.txt”,the wordcount is incremented by 1 until all
#
# the words are counted in the document.
#
# iv) Close the file.
#
# v) Create a command.py program which imports the wordcount.py program.
#
# vi) Count the number of words using command line arguments.
#
# vii) Print each word and its count.

# %%
#----->to be executed in command line interface
def count_words(filename):
    
    try:
        with open(filename, 'r') as file:
            text = file.read()
            words = text.split()
            word_count = {}
            for word in words:
                if word in word_count:
                    word_count[word] += 1
                else:
                    word_count[word] = 1
            return word_count
    
    except FileNotFoundError:
        print(f"Error: File '{filename}' not found.")
        print(sys.exc_info()[0])
        print(sys.exc_info()[1])
        
print(count_words('appple.txt'))        

import sys
if len(sys.argv) != 2:
    print("error, only two arguments are enough")
else:
    filename = sys.argv[1]
    word_count = count_words(filename)
    if word_count:
        for word, count in word_count.items():
            print(f"{word}: {count} occurrences")
# Out:
# Error: File 'appple.txt' not found.
# <class 'FileNotFoundError'>
# [Errno 2] No such file or directory: 'appple.txt'
# None
# error, only two arguments are enough

# %% [markdown]
# # 5. Write a Python program for finding the most frequent words in a text read from a file.
#
# i) Initially open the text file in read mode.
#
# ii) Make all the letters in the document into lowercase letters and split the words in each line.
#
# iii) Get the words in an order.
#
# iv) Sort the words for finding the most frequent words in the file.
#
# v) Print the most frequent words in the file.

# %%
def most_frequent_words(file_name):
    try:
        with open(file_name, 'r') as file:
            content = file.read().lower()
            words = content.split()
            word_count = {}
            for word in words:
                if word in word_count:
                    word_count[word] += 1
                else:
                    word_count[word] = 1
            sorted_word_count = sorted(word_count.items(), key=lambda x: x[1], reverse=True)
            print("Most frequent words in the file:")
            for word, count in sorted_word_count:
                print(f"{word}: {count} times")

    except FileNotFoundError:
        print(f"Error: File {file_name} not found.")
        print(sys.exc_info()[0])
        print(sys.exc_info()[1])
    

most_frequent_words('apple.txt')
# Out:
# Most frequent words in the file:
# and: 12 times
# the: 9 times
# apple: 6 times
# a: 4 times
# in: 4 times
# with: 4 times
# is: 3 times
# has: 3 times
# technology: 2 times
# steve: 2 times
# as: 2 times
# of: 2 times
# company's: 2 times
# includes: 2 times
# its: 2 times
# to: 2 times
# on: 2 times
# inc.: 1 times
# renowned: 1 times
# american: 1 times
# multinational: 1 times
# company: 1 times
# headquartered: 1 times
# cupertino,: 1 times
# california.: 1 times
# founded: 1 times
# by: 1 times
# jobs,: 1 times
# wozniak,: 1 times
# ronald: 1 times
# wayne: 1 times
# 1976,: 1 times
# since: 1 times
# emerged: 1 times
# one: 1 times
# most: 1 times
# influential: 1 times
# innovative: 1 times
# companies: 1 times
# world.: 1 times
# product: 1 times
# lineup: 1 times
# iconic: 1 times
# devices: 1 times
# such: 1 times
# iphone,: 1 times
# ipad,: 1 times
# macintosh: 1 times
# computers,: 1 times
# watch,: 1 times
# along: 1 times
# range: 1 times
# software,: 1 times
# services,: 1 times
# accessories.: 1 times
# celebrated: 1 times
# for: 1 times
# commitment: 1 times
# design: 1 times
# aesthetics,: 1 times
# user-friendly: 1 times
# interfaces,: 1 times
# cutting-edge: 1 times
# technology.: 1 times
# ecosystem,: 1 times
# which: 1 times
# app: 1 times
# store: 1 times
# icloud,: 1 times
# reshaped: 1 times
# way: 1 times
# people: 1 times
# interact: 1 times
# consume: 1 times
# content.: 1 times
# strong: 1 times
# focus: 1 times
# privacy: 1 times
# security,: 1 times
# earned: 1 times
# loyal: 1 times
# global: 1 times
# customer: 1 times
# base: 1 times
# continues: 1 times
# lead: 1 times
# areas: 1 times
# like: 1 times
# mobile: 1 times
# computing,: 1 times
# software: 1 times
# development,: 1 times
# consumer: 1 times
# electronics.: 1 times
# impact: 1 times
# tech: 1 times
# industry: 1 times
# popular: 1 times
# culture: 1 times
# immeasurable,: 1 times
# making: 1 times
# synonymous: 1 times
# innovation: 1 times
# quality: 1 times
# worldwide.: 1 times

# %% [markdown]
# # 6. File Processing with Command-Line Arguments- Scenario: You are developing a command-line utility that processes text files. Users can specify input and output file paths as command-line arguments. Your program should handle exceptions gracefully.
#
# i. Design a Python program that takes two command-line arguments: the input file path and the output file path. Ensure that the program checks if both arguments are provided and that the input file exists.
#
# ii. Implement error handling to deal with scenarios such as missing input files, invalid file paths, or permission issues when writing to the output file.
#
# iii. If an error occurs during file processing, display a user-friendly error message, and exit the program with a non-zero exit code.
#
# iv. Write test cases that cover various scenarios, including providing valid and invalid file paths as command-line arguments.

# %%
#----->to be executed in command line interface
import sys

def process_files(input_file, output_file):
    try:
        if not input_file or not output_file:
            raise ValueError("Both input and output files are required.")

        with open(input_file, 'r') as input_file:
            content = input_file.read()

        with open(output_file, 'w') as output_file:
            output_file.write(content)

        print("File processing completed successfully.")

    except FileNotFoundError:
        print(f"Error: {input_file} not found.")
        sys.exit(1)
    except PermissionError:
        print(f"Error: Permission denied when writing to output file.")
        sys.exit(1)
    except Exception as e:
        print(f"An error occurred: {str(e)}")
        sys.exit(1)

if __name__ == "__main__":
    if len(sys.argv) != 3:
        print("Usage: python program.py <input_file> <output_file>")
        sys.exit(1)

    input_file = sys.argv[1]
    output_file = sys.argv[2]

    process_files('apple.txt', 'output.txt')
# Out:
# File processing completed successfully.
